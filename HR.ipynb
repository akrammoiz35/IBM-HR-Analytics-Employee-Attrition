# %% [markdown]
# # IBM HR Analytics Employee Attrition & Performance
#
#     Below are contents of the Project :
#
#      1.Description
#      2.Importing Python Packages
#      3.Describing Dataset
#      4.Data Preprocessing
#      5.Analysis & Data Visualization
# # Description :
#      In the business world, companies often face the challenge of retaining talented employees. One of the most
#      pressing issues is the increasing rate of employee turnover, commonly known as HR attrition. Turnover can have
#      a significant impact on a company’s productivity, stability, and long-term sustainability. High attrition rates can lead
#      to increased recruitment and training costs, disrupt team dynamics, and result in the loss of valuable institutional
#      knowledge. Therefore, understanding the factors contributing to attrition and implementing effective retention
#      strategies is crucial for maintaining a competitive edge and ensuring

# %% [markdown]
# # Importing Python Packages/Libraries :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
print('Packages imported successfully')
# Out:
# Packages imported successfully

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('F:/Data science/IBM HR.csv')

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %% [markdown]
# # Describing,Preprocessing and Cleaning of Dataset :

# %%
# Get the shape of the DataFrame (number of rows and columns)
df.shape
# Out:
# (1470, 35)

# %%
# Print a summary of the DataFrame, including data types and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Calculate the number of missing values in each column
missing_values = df.isnull().sum()

# Print the missing values
missing_values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Check for duplicate rows in the DataFrame
duplicates = df.duplicated()

# Print the duplicate rows
duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
# Count the number of duplicate rows in the DataFrame
num_duplicates = df.duplicated().sum()

# Print the result
print(f'Number of duplicated data: {num_duplicates}')
# Out:
# Number of duplicated data: 0

# %%
# Calculate summary statistics for numerical columns in the DataFrame
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Drop the specified columns from the DataFrame
df = df.drop(['EmployeeCount', 'EmployeeNumber'], axis=1)

# Display the modified DataFrame
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# # Analysis & Data Visualization

# %%
# Count the occurrences of each attrition value
attrition_count = df['Attrition'].value_counts()

# Print the attrition counts
attrition_count
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# Extract attrition categories and counts
attrition = attrition_count.index
counts = attrition_count.values

# Create a bar chart
fig, ax = plt.subplots()
bars = ax.bar(attrition, counts, color=["teal", "cyan"])  # Set bar colors

# Calculate and format percentages for bar labels
percentages = [(count / counts.sum() * 100) for count in counts]
labels = [f'{p:.0f}%' for p in percentages]

# Add percentage labels to bars with padding
ax.bar_label(bars, labels=labels, padding=3)

# Set chart title and labels
ax.set_title('Attrition')
ax.set_xlabel('Attrition Category')
ax.set_ylabel('Count')

# Display the plot
plt.show()

# %%
# Count the occurrences of each business travel category
business_travel_counts = df['BusinessTravel'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(business_travel_counts,
        labels=business_travel_counts.index,  # Use category labels
        autopct='%0.2f%%',  # Format percentage with two decimals
        startangle=140,  # Start angle of the pie chart
        colors=["teal", "cyan", "turquoise"])  # Set colors for slices

# Set chart title
plt.title('Distribution of BusinessTravel Categories')

# Display the plot
plt.show()

# %%
# Count employees by department and sort
total_department = df['Department'].value_counts().sort_index()

# Calculate average daily rate by department and sort
department_avg_rate = df.groupby('Department')['DailyRate'].mean().sort_index()

# Create a dual-axis subplot figure
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot department counts with bar chart
total_department.plot(kind='bar', color="teal", width=0.8, ax=axs[0])
axs[0].set_title('Departments')
axs[0].set_xlabel("\nDepartments names")  # Add newline for better spacing
axs[0].set_ylabel("Departments counts")
axs[0].set_xticks(range(len(total_department)))
axs[0].set_xticklabels(total_department.index, rotation=45)

# Plot average daily rate by department with bar chart
department_avg_rate.plot(kind='bar', color="cyan", width=0.8, ax=axs[1])
axs[1].set_title('Average Daily Rate by Department')
axs[1].set_xlabel('Department')
axs[1].set_ylabel('Average Daily Rate')
axs[1].set_xticks(range(len(department_avg_rate)))
axs[1].set_xticklabels(department_avg_rate.index, rotation=45)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
Gender_counts = df['Gender'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(Gender_counts,
        labels=Gender_counts.index,  # Use category labels
        autopct='%0.2f%%',  # Format percentage with two decimals
        startangle=140,  # Start angle of the pie chart
        colors=["teal", "cyan", "lightcoral"])  # Set colors for slices

# Set chart title
plt.title('Distribution of Employees by Gender')

# Display the plot
plt.show()

# %%
# Group the DataFrame by 'Gender' and count the occurrences of each 'Attrition' value
attrition_by_gender = df.groupby('Gender')['Attrition'].value_counts()

# Print the results
print(attrition_by_gender)
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: Attrition, dtype: int64

# %%
# Group the DataFrame by 'Age' and count the occurrences of each 'Attrition' value
attrition_by_age = df.groupby('Age')['Attrition'].size().sort_values(ascending=False)[:10]

# Print the results
print(attrition_by_age)
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# Name: Attrition, dtype: int64

# %%
# Group the DataFrame by 'Gender' and count occurrences of each 'Attrition' value
attrition_by_gender = df.groupby('Gender')['Attrition'].value_counts()

# Group the DataFrame by 'Age' and count occurrences of each 'Attrition' value
attrition_by_age = df.groupby('Age')['Attrition'].size().sort_values(ascending=False)[:10]

# Create a dual-axis subplot figure
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot attrition by gender with bar chart
attrition_by_gender.plot(kind='bar', color='teal', width=0.8, ax=axs[0])
axs[0].set_title('Attrition by Gender')
axs[0].set_xlabel("Gender")
axs[0].set_ylabel("Attrition")
axs[0].set_xticks(range(len(attrition_by_gender)))
axs[0].set_xticklabels(attrition_by_gender.index, rotation=45)

# Plot attrition by age with bar chart
attrition_by_age.plot(kind='bar', color='cyan', width=0.8, ax=axs[1])
axs[1].set_title('Attrition by Age (Top 10)')
axs[1].set_xlabel('Age')
axs[1].set_ylabel('Attrition')
axs[1].set_xticks(range(len(attrition_by_age)))
axs[1].set_xticklabels(attrition_by_age.index, rotation=45)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Count the occurrences of each relationship satisfaction value
RS_data = df['RelationshipSatisfaction'].value_counts().sort_index(ascending=False)
RS_data
# Out:
# 4    432
# 3    459
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
len(RS_data)
# Out:
# 4

# %%
# Count the occurrences of each relationship satisfaction value
RS_data = df['RelationshipSatisfaction'].value_counts().sort_index()

# Get positions for category labels on the x-axis (0-based indexing)
x_positions = range(len(RS_data))

# Plot relationship satisfaction data
plt.plot(x_positions, RS_data.values, color='cyan', linestyle='-', linewidth=2, marker='o', label='Relationship Satisfaction')

# Update title to reflect the data being plotted
plt.title('Distribution of Relationship Satisfaction')
plt.xlabel('Relationship Satisfaction Category')  # Use descriptive label
plt.ylabel('Count')
plt.xticks(x_positions, RS_data.index, rotation=0)  # Set x-axis labels with rotation
plt.legend()  # Add legend

plt.show()

# %%
# Count the occurrences of each work-life balance value
WorkLifeBalance_count = df['WorkLifeBalance'].value_counts()

# Print the work-life balance counts
print(WorkLifeBalance_count)
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
# Count the occurrences of each environment satisfaction value
EnvironmentSatisfaction_count = df['EnvironmentSatisfaction'].value_counts()

# Print the environment satisfaction counts
print(EnvironmentSatisfaction_count)
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
# Count occurrences of each work-life balance value and sort by index
WorkLifeBalance_count = df['WorkLifeBalance'].value_counts().sort_index()

# Count occurrences of each environment satisfaction value and sort by index
EnvironmentSatisfaction_count = df['EnvironmentSatisfaction'].value_counts().sort_index()

# Create a figure with desired size
plt.figure(figsize=(12, 8))

# Plot work-life balance data
plt.plot(WorkLifeBalance_count.index, WorkLifeBalance_count.values, color='teal',
         linestyle='-', linewidth=2, marker='o', label='WorkLifeBalance')

# Plot environment satisfaction data (avoid extra spaces)
plt.plot(EnvironmentSatisfaction_count.index, EnvironmentSatisfaction_count.values, color='cyan',
         linestyle='-', linewidth=2, marker='o', label='EnvironmentSatisfaction')

# Set informative title
plt.title('Distribution of WorkLifeBalance and EnvironmentSatisfaction')

# Use descriptive labels for axes
plt.xlabel('Category Value')
plt.ylabel('Count')

# Add legend with a title
plt.legend(title='Features')

# Display the plot
plt.show()

# %%
# Count occurrences of each value in 'YearsSinceLastPromotion' and sort by index
YearsSinceLastPromotion_count = df['YearsSinceLastPromotion'].value_counts().sort_index()
YearsSinceLastPromotion_count
# Out:
# 0     581
# 1     357
# 2     159
# 3      52
# 4      61
# 5      45
# 6      32
# 7      76
# 8      18
# 9      17
# 10      6
# 11     24
# 12     10
# 13     10
# 14      9
# 15     13
# Name: YearsSinceLastPromotion, dtype: int64

# %%
# Count occurrences of each value in 'YearsSinceLastPromotion' and sort by index
YearsSinceLastPromotion_count = df['YearsSinceLastPromotion'].value_counts().sort_index()

# Create a figure with desired size (12 inches wide, 8 inches high)
plt.figure(figsize=(12, 8))
x=YearsSinceLastPromotion_count.index
y=YearsSinceLastPromotion_count.values
# Plot the data for 'YearsSinceLastPromotion' with customizations
plt.plot(x, y, color='cyan', linestyle='-', linewidth=2, marker='o', label='YearsSinceLastPromotion')

# Set informative title for the plot
plt.title('Distribution of Years Since Last Promotion')

# Label the axes for clarity
plt.xlabel('Value in YearsSinceLastPromotion')  # Use specific column name
plt.ylabel('Count')

# Add a legend to differentiate the line
plt.legend()

# Display the plot
plt.show()
